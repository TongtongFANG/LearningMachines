# %%
import glob
import os
import librosa
from librosa import display
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from matplotlib.pyplot import specgram
# %matplotlib inline
plt.style.use('ggplot')


plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.serif'] = 'Ubuntu'
plt.rcParams['font.monospace'] = 'Ubuntu Mono'
plt.rcParams['font.size'] = 12
plt.rcParams['axes.labelsize'] = 11
plt.rcParams['axes.labelweight'] = 'bold'
plt.rcParams['axes.titlesize'] = 14
plt.rcParams['xtick.labelsize'] = 10
plt.rcParams['ytick.labelsize'] = 10
plt.rcParams['legend.fontsize'] = 11
plt.rcParams['figure.titlesize'] = 13

# %%
file_folder = './dataset_tmp'


sound_file_names = ["0ab3b47d_nohash_0.wav",
                    "0ab3b47d_nohash_1.wav",
                    "0a9f9af7_nohash_0.wav",
                    "0ab3b47d_nohash_0.wav",
                    "0a7c2a8d_nohash_1.wav"]

sound_class_names = ["down","go","left","right","up"]

sound_file_paths = list(map(lambda f_tup: os.path.join(file_folder, f_tup[0], f_tup[1]), 
                            zip(sound_class_names, sound_file_names)))

print(sound_file_paths)
# Out:
# ['./dataset_tmp/down/0ab3b47d_nohash_0.wav', './dataset_tmp/go/0ab3b47d_nohash_1.wav', './dataset_tmp/left/0a9f9af7_nohash_0.wav', './dataset_tmp/right/0ab3b47d_nohash_0.wav', './dataset_tmp/up/0a7c2a8d_nohash_1.wav']

# %%
def plot_specgram(file_paths):
    for idx, file_path in enumerate(file_paths):
        
        plt.figure(figsize=(10, 4))
        X, sample_rate = librosa.load(file_path, sr=None)

        specgram(X, Fs=sample_rate)
        plt.title(sound_class_names[idx])
        plt.show()

plot_specgram(sound_file_paths)
